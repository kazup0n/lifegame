# %%
class Board:
    
    def __init__(self):
        self.cells = [[False]*3]*3

# %%
-
# Out:
# □■■■■■■□□■
# ■□□□□□■■□■
# □□■□□■■□□□
# ■■■■□■□□■□
# ■□■■■■□□□■
# □■□■■■□□□■
# □■■□□□□■■■
# □■□□■■■■□□
# ■■■□■□□■□□
# ■□■■□□□■□■
#
# □■■■■■■■■□
# □□□□□□□■■□
# ■□■■■■□□■□
# ■□□□□□□□□□
# ■□□□□□■□■■
# ■□□□□■■□□■
# ■■□□□□□■□■
# □□□□■■□□□□
# ■□□□■□□■□□
# ■□■■□□□□■□
#
# □□■■■■■□■□
# □□□□□□□□□■
# □■□■■□□■■□
# ■□□■■■□■■■
# ■■□□□■■■■■
# ■□□□□■■□□■
# ■■□□■□□□■□
# ■■□□■■■□■□
# □■□□■■□□□□
# □■□■□□□□□□
#
# □□□■■■□□□□
# □□□□□□■□□■
# □□■■□■■■□□
# ■□□■□□□□□□
# ■■□□□□□□□□
# □□□□■□□□□■
# □□□□■□□□■■
# □□■■□□■■□□
# □■□■□□■□□□
# □□■□■□□□□□
#
# □□□□■■□□□□
# □□■□□□□■□□
# □□■■■■■■□□
# ■□□■■□■□□□
# ■■□□□□□□□□
# □□□□□□□□■■
# □□□□■■□■■■
# □□■■■■■■■□
# □■□□■■■■□□
# □□■■□□□□□□
#
# □□□□□□□□□□
# □□■□□□□■□□
# □■■□□□□■□□
# ■□□□□□■■□□
# ■■□□□□□□□□
# □□□□□□□■□■
# □□□□□□□□□□
# □□■□□□□□□■
# □■□□□□□□■□
# □□■■■■■□□□
#
# □□□□□□□□□□
# □■■□□□□□□□
# □■■□□□□■■□
# ■□■□□□■■□□
# ■■□□□□■■■□
# □□□□□□□□□□
# □□□□□□□□■□
# □□□□□□□□□□
# □■□□■■□□□□
# □□■■■■□□□□
#
# □□□□□□□□□□
# □■■□□□□□□□
# ■□□■□□■■■□
# ■□■□□□□□□□
# ■■□□□□■□■□
# ...

# %%
print('a' if 1==1 else 'b')
# Out:
# a
